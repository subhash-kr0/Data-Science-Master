# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/credit_card_pw_hindi/main/creditCardFraud_28011964_120214.csv")

# %% [markdown]
# LIMIT_BAL: This feature represents the credit limit assigned to the individual's credit card. It indicates the maximum amount of credit the person can utilize.
#
# SEX: This feature represents the gender of the credit card holder. While gender itself may not directly impact credit card fault detection, it can be considered as a demographic factor that might have some influence on creditworthiness.
#
# EDUCATION: This feature indicates the educational background of the credit card holder. It can provide insights into the person's level of education, which might indirectly correlate with their financial stability and ability to manage credit.
#
# MARRIAGE: This feature represents the marital status of the credit card holder. Similar to gender, marital status can be a demographic factor that could potentially impact credit card fault detection.
#
# AGE: This feature denotes the age of the credit card holder. Age can be an important factor in assessing creditworthiness as it often correlates with financial responsibility and stability.
#
# PAY_0, PAY_2, PAY_3, PAY_4, PAY_5, PAY_6: These features represent the repayment status of the credit card for the past six months. The values indicate the payment status (e.g., -1 represents payment delay for one month, 0 represents payment on time, 1 represents payment delay for two months, and so on). These features are crucial in determining the payment behavior of the individual over time.
#
# BILL_AMT1, BILL_AMT2, BILL_AMT3, BILL_AMT4, BILL_AMT5, BILL_AMT6: These features represent the amount of bill statement for the respective months. They provide information about the outstanding balance on the credit card at specific points in time.
#
# PAY_AMT1, PAY_AMT2, PAY_AMT3, PAY_AMT4, PAY_AMT5, PAY_AMT6: These features represent the amount of payment made by the credit card holder for the respective months. They indicate the actual payments made to reduce the outstanding balance.
#
# default payment next month: This is the target variable or the dependent variable that indicates whether the credit card holder defaulted on their payment in the following month (1 for default, 0 for no default). This is the variable that the credit card fault detection model aims to predict.

# %%
data
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
#       PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         0  ...      20940      19146      19131      2000     36681
# 1         0  ...      19394      19619      20024      2500      1815
# 2         0  ...     542653     483003     473944     55000     40000
# 3         0  ...        221       -159        567       380       601
# 4         0  ...      12211      11793       3719      3329         0
# ...     ...  ...        ...        ...        ...       ...       ...
# 996      -1  ...      -2618      95748     101299      3320      5000
# 997       0  ...      97041     103541       3632      5000      2000
# 998      -1  ...        657       1332        780         0      2806
# 999      -2  ...          0          0          0         0         0
# 1000     -2  ...       2527          0          0      9664      3420
#
#       PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0        10000      9000       689       679                           0
# 1          657      1000      1000       800                           0
# 2        38000     20239     13750     13770                           0
# 3            0       581      1687      1542                           0
# 4          432      1000      1000      1000                           0
# ...        ...       ...       ...       ...                         ...
# 996          0    100000      7186         0                           0
# 997      89000      6500        91      1504                           0
# 998       2256      2274       780         0                           0
# 999          0         0         0         0                           1
# 1000      2612         0         0         0                           1
#
# [1001 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
#  13  BILL_AMT3                   1001 non-null   int64
#  14  BILL_AMT4                   1001 non-null   int64
#  15  BILL_AMT5                   1001 non-null   int64
#  16  BILL_AMT6                   1001 non-null   int64
#  17  PAY_AMT1                    1001 non-null   int64
#  18  PAY_AMT2                    1001 non-null   int64
#  19  PAY_AMT3                    1001 non-null   int64
#  20  PAY_AMT4                    1001 non-null   int64
#  21  PAY_AMT5                    1001 non-null   int64
#  22  PAY_AMT6                    1001 non-null   int64
#  23  default payment next month  1001 non-null   int64
# dtypes: int64(24)
# memory usage: 187.8 KB

# %%
data.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
data.describe().T
# Out:
#                              count           mean            std       min  \
# LIMIT_BAL                   1001.0  167532.467532  130587.921320   10000.0
# SEX                         1001.0       1.589411       0.492187       1.0
# EDUCATION                   1001.0       1.776224       0.750916       1.0
# MARRIAGE                    1001.0       1.604396       0.532298       0.0
# AGE                         1001.0      34.945055       9.219760      21.0
# PAY_0                       1001.0      -0.004995       1.173446      -2.0
# PAY_2                       1001.0      -0.161838       1.228732      -2.0
# PAY_3                       1001.0      -0.164835       1.262459      -2.0
# PAY_4                       1001.0      -0.283716       1.184662      -2.0
# PAY_5                       1001.0      -0.283716       1.170224      -2.0
# PAY_6                       1001.0      -0.314685       1.203276      -2.0
# BILL_AMT1                   1001.0   49386.738262   72657.966256  -14386.0
# BILL_AMT2                   1001.0   47879.345654   72090.718188  -13543.0
# BILL_AMT3                   1001.0   44925.682318   69545.948045   -9850.0
# BILL_AMT4                   1001.0   40748.408591   68206.929510   -3684.0
# BILL_AMT5                   1001.0   39078.666334   63108.238729  -28335.0
# BILL_AMT6                   1001.0   38012.011988   63074.415024 -339603.0
# PAY_AMT1                    1001.0    5382.339660   12180.755275       0.0
# PAY_AMT2                    1001.0    5051.400599   15626.153184       0.0
# PAY_AMT3                    1001.0    4176.149850   10514.647502       0.0
# PAY_AMT4                    1001.0    4671.488511   13269.943983       0.0
# PAY_AMT5                    1001.0    5331.049950   16812.536877       0.0
# PAY_AMT6                    1001.0    5090.704296   23658.888052       0.0
# default payment next month  1001.0       0.213786       0.410183       0.0
#
#                                 25%       50%       75%       max
# LIMIT_BAL                   50000.0  140000.0  240000.0  700000.0
# SEX                             1.0       2.0       2.0       2.0
# EDUCATION                       1.0       2.0       2.0       6.0
# MARRIAGE                        1.0       2.0       2.0       3.0
# AGE                            28.0      33.0      41.0      75.0
# PAY_0                          -1.0       0.0       0.0       8.0
# PAY_2                          -1.0       0.0       0.0       7.0
# PAY_3                          -1.0       0.0       0.0       7.0
# PAY_4                          -1.0       0.0       0.0       7.0
# PAY_5                          -1.0       0.0       0.0       7.0
# PAY_6                          -1.0       0.0       0.0       7.0
# BILL_AMT1                    3128.0   21075.0   59901.0  507726.0
# BILL_AMT2                    3274.0   20400.0   58472.0  509229.0
# BILL_AMT3                    1940.0   19292.0   54477.0  499936.0
# BILL_AMT4                    1423.0   17710.0   48851.0  628699.0
# BILL_AMT5                    1206.0   17580.0   46404.0  484612.0
# BILL_AMT6                     830.0   15846.0   46557.0  473944.0
# PAY_AMT1                     1000.0    2184.0    5090.0  199646.0
# PAY_AMT2                      390.0    1710.0    4500.0  285138.0
# PAY_AMT3                      228.0    1206.0    3720.0  133657.0
# PAY_AMT4                      148.0    1398.0    4000.0  188840.0
# PAY_AMT5                      189.0    1306.0    3745.0  195599.0
# PAY_AMT6                        0.0    1250.0    3784.0  528666.0
# default payment next month      0.0       0.0       0.0       1.0

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile=ProfileReport(data,title="pandas profiling report")

# %%
profile.to_widgets()
# Out:
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
X=data.drop(labels=['default payment next month'],axis=1)

# %%
X
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
#       PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0         0  ...      35835      20940      19146      19131      2000
# 1         0  ...      57608      19394      19619      20024      2500
# 2         0  ...     445007     542653     483003     473944     55000
# 3         0  ...        601        221       -159        567       380
# 4         0  ...      12108      12211      11793       3719      3329
# ...     ...  ...        ...        ...        ...        ...       ...
# 996      -1  ...      67782      -2618      95748     101299      3320
# 997       0  ...       8441      97041     103541       3632      5000
# 998      -1  ...       1114        657       1332        780         0
# 999      -2  ...          0          0          0          0         0
# 1000     -2  ...       3420       2527          0          0      9664
#
#       PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0        36681     10000      9000       689       679
# 1         1815       657      1000      1000       800
# 2        40000     38000     20239     13750     13770
# 3          601         0       581      1687      1542
# 4            0       432      1000      1000      1000
# ...        ...       ...       ...       ...       ...
# 996       5000         0    100000      7186         0
# 997       2000     89000      6500        91      1504
# 998       2806      2256      2274       780         0
# 999          0         0         0         0         0
# 1000      3420      2612         0         0         0
#
# [1001 rows x 23 columns]

# %%
y=data['default payment next month']

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     0
# 998     0
# 999     1
# 1000    1
# Name: default payment next month, Length: 1001, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=20)

# %%
X_train
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 900      80000    2          2         2   40      2      0      0      0
# 439     200000    2          1         2   27      0      0      0      0
# 614      60000    1          1         2   25      0      0      0      0
# 696     400000    2          2         2   40     -2     -2     -2     -2
# 128     420000    1          2         1   34      0      0      0      0
# ..         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 924     180000    2          1         2   36     -2     -2     -2     -2
# 223      20000    1          2         1   37      0      0      0      0
# 271      70000    2          2         2   36      0      0      0      0
# 474     500000    2          1         1   38     -1      2     -1     -1
# 355     260000    1          1         1   34     -1     -1     -1     -1
#
#      PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 900      2  ...      59863      62860      63976      63293      2200
# 439      0  ...     126355     114881     117213     124793      5704
# 614      0  ...      38533      39639      39619      39140      2018
# 696     -1  ...          0          0       1524          0      8235
# 128      0  ...     229049     220951     210606     188108      9744
# ..     ...  ...        ...        ...        ...        ...       ...
# 924     -2  ...      11936      40420       9210      17795     21197
# 223      0  ...      18902      18768      18650      19175      1609
# 271      0  ...      68376      30163      14310      15085      4483
# 474     -1  ...        501        300        600        450         0
# 355     -1  ...      51058       2351      34039        291       291
#
#      PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 900      2200      4000      1777         0      2000
# 439      5930      4000      4003     10033      4400
# 614      1900      2000      1500      1900      2000
# 696         0         0      1524         0       385
# 128      9553      7603      7830      7253     11326
# ..        ...       ...       ...       ...       ...
# 924     11936     40420      9210     17795      6915
# 223      3000       663       676       834       782
# 271     12496      3268      3000      3000      2000
# 474       501       300       600       300       600
# 355     51058     35696     34039       291       291
#
# [750 rows x 23 columns]

# %%
X_test
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 891     200000    1          1         2   31     -2     -2     -2     -2
# 694     280000    1          1         1   41     -2     -2     -2     -2
# 798      50000    2          3         1   44     -1     -1     -1     -1
# 147      80000    1          1         2   25      0      0      0      0
# 859      10000    2          2         1   31      0      0      0      0
# ..         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 172      80000    1          1         2   30     -2     -1      0      0
# 835     500000    1          1         1   43      1     -2     -2     -2
# 601      50000    1          1         2   34      1      2      2      2
# 171     130000    1          3         1   56      1      2      2      2
# 826     320000    1          1         2   28     -1      0      0     -1
#
#      PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 891     -2  ...        100        100        100        100       100
# 694     -1  ...      51500      35752       3955      13969     41346
# 798      0  ...          0       7472      10174      11104       780
# 147      0  ...      43476      41087      41951      31826     30000
# 859      0  ...       9901       9975       9736       8703      2330
# ..     ...  ...        ...        ...        ...        ...       ...
# 172      0  ...        600       1438       1919       5380       504
# 835     -2  ...          0          0          0          0         0
# 601      2  ...      24121      23437      25101      24549         0
# 171      2  ...      67282      68557      72796      71345      3000
# 826      0  ...       3037       1633       3633          0      2000
#
#      PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 891       100       100       100       100       100
# 694     52110     35752      3955     13939      4437
# 798         0      7472      3000      1104      1000
# 147      3000      6000      8000      2000     14000
# 859      2200      1000       333       311       322
# ..        ...       ...       ...       ...       ...
# 172       500      1000       500      3500         0
# 835         0         0         0         0         0
# 601      2700         0      2200         0      1030
# 171      3000      3000      5500         0         0
# 826      1000      1633      2000         0      3000
#
# [251 rows x 23 columns]

# %%
X_train
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 900      80000    2          2         2   40      2      0      0      0
# 439     200000    2          1         2   27      0      0      0      0
# 614      60000    1          1         2   25      0      0      0      0
# 696     400000    2          2         2   40     -2     -2     -2     -2
# 128     420000    1          2         1   34      0      0      0      0
# ..         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 924     180000    2          1         2   36     -2     -2     -2     -2
# 223      20000    1          2         1   37      0      0      0      0
# 271      70000    2          2         2   36      0      0      0      0
# 474     500000    2          1         1   38     -1      2     -1     -1
# 355     260000    1          1         1   34     -1     -1     -1     -1
#
#      PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 900      2  ...      59863      62860      63976      63293      2200
# 439      0  ...     126355     114881     117213     124793      5704
# 614      0  ...      38533      39639      39619      39140      2018
# 696     -1  ...          0          0       1524          0      8235
# 128      0  ...     229049     220951     210606     188108      9744
# ..     ...  ...        ...        ...        ...        ...       ...
# 924     -2  ...      11936      40420       9210      17795     21197
# 223      0  ...      18902      18768      18650      19175      1609
# 271      0  ...      68376      30163      14310      15085      4483
# 474     -1  ...        501        300        600        450         0
# 355     -1  ...      51058       2351      34039        291       291
#
#      PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 900      2200      4000      1777         0      2000
# 439      5930      4000      4003     10033      4400
# 614      1900      2000      1500      1900      2000
# 696         0         0      1524         0       385
# 128      9553      7603      7830      7253     11326
# ..        ...       ...       ...       ...       ...
# 924     11936     40420      9210     17795      6915
# 223      3000       663       676       834       782
# 271     12496      3268      3000      3000      2000
# 474       501       300       600       300       600
# 355     51058     35696     34039       291       291
#
# [750 rows x 23 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaled_train=scaler.fit_transform(X_train)
scaled_test=scaler.transform(X_test)

# %%
[10,20,30,40,50]
# Out:
# [10, 20, 30, 40, 50]

# %%
df=pd.DataFrame([10,20,30,40,50])

# %%
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
import numpy as np
mean=np.mean([10,20,30,40,50])

# %%
meanbycol=df-mean

# %%
std=np.std([10,20,30,40,50])

# %%
meanbycol/std
# Out:
#           0
# 0 -1.414214
# 1 -0.707107
# 2  0.000000
# 3  0.707107
# 4  1.414214

# %%
new_obj=StandardScaler()

# %%
scale_data=new_obj.fit_transform(df)

# %%
scale_data
# Out:
# array([[-1.41421356],
#        [-0.70710678],
#        [ 0.        ],
#        [ 0.70710678],
#        [ 1.41421356]])

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(scaled_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import accuracy_score 
y_pred=clf.predict(scaled_test)
accuracy_score(y_test,y_pred)*100
# Out:
# 70.5179282868526

# %%
hyperparameter tuning concept

# %%
param_grid={"var_smoothing":[0.1, 0.001, 0.5,0.05,0.01,1e-8,1e-7,1e-6,1e-10,1e-11]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
gs=GridSearchCV(clf,param_grid=param_grid,cv=5,verbose=3)

# %%
gs.fit(scaled_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .................var_smoothing=0.1;, score=0.800 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.720 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.707 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.800 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.547 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=0.001;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=0.001;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=0.001;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=0.001;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=0.001;, score=0.447 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.5;, score=0.793 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.5;, score=0.767 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.5;, score=0.747 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.5;, score=0.800 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.5;, score=0.740 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.05;, score=0.800 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.05;, score=0.713 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.05;, score=0.693 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.05;, score=0.747 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.05;, score=0.493 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.01;, score=0.800 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.01;, score=0.707 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.01;, score=0.647 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.01;, score=0.680 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.01;, score=0.467 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-08;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-08;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-08;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-08;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-08;, score=0.447 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-07;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-07;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-07;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-07;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-07;, score=0.447 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-06;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-06;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-06;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-06;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-06;, score=0.447 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-10;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-10;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-10;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-10;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-10;, score=0.447 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-11;, score=0.793 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-11;, score=0.713 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-11;, score=0.633 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-11;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-11;, score=0.447 total time=   0.0s
# GridSearchCV(cv=5, estimator=GaussianNB(),
#              param_grid={'var_smoothing': [0.1, 0.001, 0.5, 0.05, 0.01, 1e-08,
#                                            1e-07, 1e-06, 1e-10, 1e-11]},
#              verbose=3)

# %%
gs.best_params_
# Out:
# {'var_smoothing': 0.5}

# %%
from sklearn.naive_bayes import GaussianNB
clf1 = GaussianNB(var_smoothing=0.5)
clf1.fit(scaled_train,y_train)
y_pred1=clf1.predict(scaled_test)
accuracy_score(y_test,y_pred1)*100
# Out:
# 80.47808764940238

# %%
from sklearn.ensemble import RandomForestClassifier
rs=RandomForestClassifier()
rs.fit(scaled_train,y_train)
y_pred2=rs.predict(scaled_test)
accuracy_score(y_test,y_pred2)*100
# Out:
# 83.26693227091634

# %%
param_grid_rf = { "n_estimators": [50,100,130,200],
                    "max_depth": range(3,11,1),
                    "random_state":[0,50,100],
                     "criterion":['gini',"entropy"]
                     }

# %%
gs1=GridSearchCV(rs,param_grid=param_grid_rf,cv=5,verbose=3)

# %%
gs1.fit(scaled_train,y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.760 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.780 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=100;, score=0.760 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=0;, score=0.767 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.800 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.807 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=50;, score=0.773 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.800 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=100, random_state=100;, score=0.773 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.793 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=0;, score=0.767 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.773 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.807 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=50;, score=0.773 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.773 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.793 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=130, random_state=100;, score=0.767 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.787 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=0;, score=0.767 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=50;, score=0.767 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.793 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.787 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=200, random_state=100;, score=0.767 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.773 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.753 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=0;, score=0.760 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.773 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=50;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=50, random_state=100;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.747 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=0;, score=0.760 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.773 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.813 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=50;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=100, random_state=100;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.773 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.773 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=50;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.773 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.780 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=130, random_state=100;, score=0.753 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.773 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.773 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.793 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=50;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.793 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=4, n_estimators=200, random_state=100;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.773 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=0;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=50;, score=0.767 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=50, random_state=100;, score=0.760 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.773 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.807 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=50;, score=0.753 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=100, random_state=100;, score=0.760 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.773 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.767 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=50;, score=0.753 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=130, random_state=100;, score=0.753 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.773 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.767 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.773 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=0;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.767 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=50;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=5, n_estimators=200, random_state=100;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=0;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.800 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.767 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.787 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=50;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.753 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.767 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=50, random_state=100;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=0;, score=0.740 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.793 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.747 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=50;, score=0.740 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.780 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=100, random_state=100;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.780 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=0;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.800 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=50;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=130, random_state=100;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.780 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=0;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.780 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=50;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.787 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=6, n_estimators=200, random_state=100;, score=0.753 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.773 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.820 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=0;, score=0.740 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.773 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.787 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=50;, score=0.767 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.753 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.773 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.813 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=50, random_state=100;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.780 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=50;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=100, random_state=100;, score=0.773 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.820 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=50;, score=0.740 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.793 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=130, random_state=100;, score=0.773 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.767 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=0;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.773 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=50;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.767 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.820 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=7, n_estimators=200, random_state=100;, score=0.767 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.773 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=0;, score=0.760 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.800 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=50;, score=0.767 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.807 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=50, random_state=100;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.793 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.800 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.787 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.793 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=50;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.793 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=100, random_state=100;, score=0.760 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.773 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.793 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=0;, score=0.740 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=50;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.760 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.820 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=130, random_state=100;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.767 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=0;, score=0.733 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.800 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=50;, score=0.740 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=8, n_estimators=200, random_state=100;, score=0.740 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.827 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.820 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=0;, score=0.733 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.807 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.813 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=50;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.807 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=50, random_state=100;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.800 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.747 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.807 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=0;, score=0.727 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.820 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=50;, score=0.740 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=100, random_state=100;, score=0.753 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.793 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.747 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=0;, score=0.727 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.793 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.813 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=50;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.800 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.793 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=130, random_state=100;, score=0.767 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.807 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.800 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.813 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=0;, score=0.727 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.787 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=50;, score=0.720 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.787 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.793 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=9, n_estimators=200, random_state=100;, score=0.767 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.793 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=0;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=50;, score=0.753 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.800 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=50, random_state=100;, score=0.733 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.773 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.827 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, n_estimators=100, random_state=0;, score=0.753 total time=   0.0s
# ...
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=130, random_state=100;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=130, random_state=100;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=130, random_state=100;, score=0.820 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=130, random_state=100;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.807 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.773 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.813 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=0;, score=0.740 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.747 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.787 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.800 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=50;, score=0.753 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.800 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.767 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.813 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=8, n_estimators=200, random_state=100;, score=0.747 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.780 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=0;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.813 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.760 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.787 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.773 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=50;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.753 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.813 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=50, random_state=100;, score=0.747 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.787 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.773 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.780 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=0;, score=0.740 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.780 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.793 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=50;, score=0.753 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.793 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=100, random_state=100;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.793 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.780 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.780 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=0;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.773 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.753 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=50;, score=0.753 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.800 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=130, random_state=100;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.800 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.780 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.780 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.807 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=0;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.793 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.800 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=50;, score=0.747 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.753 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.813 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=9, n_estimators=200, random_state=100;, score=0.753 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.753 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.800 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=0;, score=0.733 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.813 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.747 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.787 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=50;, score=0.740 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.800 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.793 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.813 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=50, random_state=100;, score=0.760 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.787 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=0;, score=0.740 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.800 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.753 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.787 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=50;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.807 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.747 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.793 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.800 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=100, random_state=100;, score=0.760 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.773 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.787 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.800 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=0;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.793 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.760 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=50;, score=0.747 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.807 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.747 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.800 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.807 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=130, random_state=100;, score=0.753 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.787 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.760 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.780 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.807 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=0;, score=0.753 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.780 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.760 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.787 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.807 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=50;, score=0.740 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.813 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.747 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.800 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.807 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, n_estimators=200, random_state=100;, score=0.760 total time=   0.3s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(3, 11),
#                          'n_estimators': [50, 100, 130, 200],
#                          'random_state': [0, 50, 100]},
#              verbose=3)

# %%
gs1.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 100, 'random_state': 0}

# %%
from sklearn.ensemble import RandomForestClassifier
rs1=RandomForestClassifier(criterion='gini',n_estimators= 1200,random_state=0)
rs1.fit(scaled_train,y_train)
y_pred3=rs1.predict(scaled_test)
accuracy_score(y_test,y_pred3)*100
# Out:
# 83.26693227091634

# %%
84.06374501992032-83.26693227091634
# Out:
# 0.7968127490039763

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()
xgb.fit(scaled_train,y_train)
y_pred4=xgb.predict(scaled_test)
accuracy_score(y_test,y_pred4)*100
# Out:
# 80.47808764940238

# %%
# check with the accuracy whether it is increasing or not
# do hyperparameter tuning for the xgboost
